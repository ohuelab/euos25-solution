# %%
import pandas as pd

# %%
df = pd.read_csv("../data/submissions/submission_20251102_053145.csv")
fluo_480_df = pd.read_csv("../data/submissions/full_focal/fluo_480_20251102_063449.csv")
df["Fluorescence(multiple)"] = fluo_480_df["prediction"]
df.to_csv("../data/submissions/submission_20251102_053145_v2.csv", index=False) # add focal loss

# %%
import matplotlib.pyplot as plt
